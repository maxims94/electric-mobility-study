# %% [markdown]
# # Dataset 1: Cleaning

# %%
import pandas as pd
import numpy as np
from pprint import pprint

# %% [markdown]
# Source: Eurostat, dataset [road_eqr_carpda](http://appsso.eurostat.ec.europa.eu/nui/show.do?dataset=road_eqr_carpda&lang=en)

# %%
df_orig = pd.read_csv("../data/road_eqr_carpda_1_Data.csv", encoding="ISO-8859-1",na_values=[":"])
df = df_orig.copy()
print(df.head())
print(df.tail())
print(df.columns)
# Out:
#    TIME      GEO    UNIT                          MOT_NRG    Value  \
# 0  2013  Belgium  Number               Petroleum products  169,665
# 1  2013  Belgium  Number  Liquefied petroleum gases (LPG)      NaN
# 2  2013  Belgium  Number                           Diesel  319,863
# 3  2013  Belgium  Number                      Natural Gas      109
# 4  2013  Belgium  Number                      Electricity      501
#
#   Flag and Footnotes
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#       TIME     GEO    UNIT                   MOT_NRG Value Flag and Footnotes
# 2375  2017  Turkey  Number  Hydrogen and fuel cells      0                NaN
# 2376  2017  Turkey  Number                Bioethanol     0                NaN
# 2377  2017  Turkey  Number                 Biodiesel     0                NaN
# 2378  2017  Turkey  Number                   Bi-fuel     0                NaN
# 2379  2017  Turkey  Number                     Other     0                NaN
# Index(['TIME', 'GEO', 'UNIT', 'MOT_NRG', 'Value', 'Flag and Footnotes'], dtype='object')

# %% [markdown]
# ## Column: Flag and Footnotes

# %%
print(df["Flag and Footnotes"].unique())
df[df["Flag and Footnotes"] == 'd']
# Out:
# [nan 'd']
#       TIME             GEO    UNIT                           MOT_NRG  \
# 7     2013         Belgium  Number            Hybrid electric-petrol
# 10    2013         Belgium  Number            Hybrid diesel-electric
# 58    2013         Estonia  Number            Hybrid electric-petrol
# 61    2013         Estonia  Number            Hybrid diesel-electric
# 136   2013           Italy  Number                Petroleum products
# 138   2013           Italy  Number                            Diesel
# 142   2013           Italy  Number      Petrol (excluding hybrids)
# 153   2013          Cyprus  Number                Petroleum products
# 155   2013          Cyprus  Number                            Diesel
# 204   2013         Hungary  Number                Petroleum products
# 206   2013         Hungary  Number                            Diesel
# 207   2013         Hungary  Number                       Natural Gas
# 209   2013         Hungary  Number                Alternative Energy
# 219   2013         Hungary  Number                           Bi-fuel
# 220   2013         Hungary  Number                             Other
# 534   2014         Estonia  Number            Hybrid electric-petrol
# 537   2014         Estonia  Number            Hybrid diesel-electric
# 561   2014           Spain  Number                Petroleum products
# 562   2014           Spain  Number   Liquefied petroleum gases (LPG)
# 563   2014           Spain  Number                            Diesel
# 564   2014           Spain  Number                       Natural Gas
# 565   2014           Spain  Number                       Electricity
# 566   2014           Spain  Number                Alternative Energy
# 567   2014           Spain  Number      Petrol (excluding hybrids)
# 568   2014           Spain  Number            Hybrid electric-petrol
# 569   2014           Spain  Number  Plug-in hybrid petrol-electric
# 570   2014           Spain  Number      Diesel (excluding hybrids)
# 571   2014           Spain  Number            Hybrid diesel-electric
# 572   2014           Spain  Number  Plug-in hybrid diesel-electric
# 573   2014           Spain  Number          Hydrogen and fuel cells
# ...    ...             ...     ...                               ...
# 2196  2017        Portugal  Number                       Natural Gas
# 2197  2017        Portugal  Number                       Electricity
# 2198  2017        Portugal  Number                Alternative Energy
# 2199  2017        Portugal  Number      Petrol (excluding hybrids)
# 2200  2017        Portugal  Number            Hybrid electric-petrol
# 2202  2017        Portugal  Number      Diesel (excluding hybrids)
# 2203  2017        Portugal  Number            Hybrid diesel-electric
# 2205  2017        Portugal  Number          Hydrogen and fuel cells
# 2206  2017        Portugal  Number                        Bioethanol
# 2207  2017        Portugal  Number                         Biodiesel
# 2208  2017        Portugal  Number                           Bi-fuel
# 2209  2017        Portugal  Number                             Other
# 2213  2017         Romania  Number                       Natural Gas
# 2232  2017        Slovenia  Number                Alternative Energy
# 2278  2017  United Kingdom  Number                Petroleum products
# 2280  2017  United Kingdom  Number                            Diesel
# 2281  2017  United Kingdom  Number                       Natural Gas
# 2282  2017  United Kingdom  Number                       Electricity
# 2283  2017  United Kingdom  Number                Alternative Energy
# 2284  2017  United Kingdom  Number      Petrol (excluding hybrids)
# 2285  2017  United Kingdom  Number            Hybrid electric-petrol
# 2286  2017  United Kingdom  Number  Plug-in hybrid petrol-electric
# 2287  2017  United Kingdom  Number      Diesel (excluding hybrids)
# 2288  2017  United Kingdom  Number            Hybrid diesel-electric
# 2289  2017  United Kingdom  Number  Plug-in hybrid diesel-electric
# 2293  2017  United Kingdom  Number                           Bi-fuel
# 2294  2017  United Kingdom  Number                             Other
# 2315  2017          Norway  Number                       Natural Gas
# 2336  2017     Switzerland  Number            Hybrid electric-petrol
# 2339  2017     Switzerland  Number            Hybrid diesel-electric
#
#           Value Flag and Footnotes
# 7         4,920                  d
# 10          912                  d
# 58          191                  d
# 61            4                  d
# 136     419,045                  d
# 138     707,641                  d
# 142     419,045                  d
# 153      11,758                  d
# 155       2,998                  d
# 204      52,677                  d
# 206      72,343                  d
# 207         244                  d
# 209       1,917                  d
# 219         796                  d
# 220         857                  d
# 534         308                  d
# 537           3                  d
# 561     297,176                  d
# 562       1,108                  d
# 563     590,360                  d
# 564         127                  d
# 565       1,181                  d
# 566       2,589                  d
# 567     288,860                  d
# 568       8,070                  d
# 569         246                  d
# 570     590,198                  d
# 571         139                  d
# 572          23                  d
# 573           0                  d
# ...         ...                ...
# 2196          7                  d
# 2197      1,912                  d
# 2198      6,248                  d
# 2199     74,356                  d
# 2200      4,319                  d
# 2202    138,712                  d
# 2203        394                  d
# 2205          0                  d
# 2206          0                  d
# 2207          0                  d
# 2208          0                  d
# 2209      2,534                  d
# 2213        424                  d
# 2232      1,838                  d
# 2278  1,446,500                  d
# 2280  1,049,086                  d
# 2281          3                  d
# 2282     13,727                  d
# 2283     13,744                  d
# 2284  1,342,152                  d
# 2285     70,123                  d
# 2286     34,225                  d
# 2287  1,047,685                  d
# 2288        783                  d
# 2289        618                  d
# 2293         11                  d
# 2294          3                  d
# 2315         37                  d
# 2336     11,600                  d
# 2339        300                  d
#
# [147 rows x 6 columns]

# %%
# 'd' means "definition differs"
# Assume for simplicity that it is the same

df = df.drop("Flag and Footnotes",axis=1)

# %% [markdown]
# ## Column: UNIT

# %%
df.UNIT.unique()
# Out:
# array(['Number'], dtype=object)

# %%
df = df.drop("UNIT",axis=1)

# %% [markdown]
# ## Change column names

# %%
df.columns = ["time","country","motor","value"]
df.head()
# Out:
#    time  country                            motor    value
# 0  2013  Belgium               Petroleum products  169,665
# 1  2013  Belgium  Liquefied petroleum gases (LPG)      NaN
# 2  2013  Belgium                           Diesel  319,863
# 3  2013  Belgium                      Natural Gas      109
# 4  2013  Belgium                      Electricity      501

# %% [markdown]
# ## Column: country

# %%
df.country.unique()
# Out:
# array(['Belgium', 'Denmark',
#        'Germany (until 1990 former territory of the FRG)', 'Estonia',
#        'Ireland', 'Spain', 'France', 'Croatia', 'Italy', 'Cyprus',
#        'Latvia', 'Lithuania', 'Hungary', 'Malta', 'Netherlands',
#        'Austria', 'Poland', 'Portugal', 'Romania', 'Slovenia', 'Finland',
#        'Sweden', 'United Kingdom', 'Liechtenstein', 'Norway',
#        'Switzerland', 'North Macedonia', 'Turkey'], dtype=object)

# %%
df.country.replace(to_replace='Germany (until 1990 former territory of the FRG)', value='Germany', inplace=True)
df.country.unique()
# Out:
# array(['Belgium', 'Denmark', 'Germany', 'Estonia', 'Ireland', 'Spain',
#        'France', 'Croatia', 'Italy', 'Cyprus', 'Latvia', 'Lithuania',
#        'Hungary', 'Malta', 'Netherlands', 'Austria', 'Poland', 'Portugal',
#        'Romania', 'Slovenia', 'Finland', 'Sweden', 'United Kingdom',
#        'Liechtenstein', 'Norway', 'Switzerland', 'North Macedonia',
#        'Turkey'], dtype=object)

# %% [markdown]
# ## Column: value

# %%
df[[pd.isnull(x) for x in df.value]]
# Out:
#       time          country                             motor value
# 1     2013          Belgium   Liquefied petroleum gases (LPG)   NaN
# 8     2013          Belgium  Plug-in hybrid petrol-electric     NaN
# 11    2013          Belgium  Plug-in hybrid diesel-electric     NaN
# 12    2013          Belgium          Hydrogen and fuel cells    NaN
# 13    2013          Belgium                        Bioethanol   NaN
# 14    2013          Belgium                         Biodiesel   NaN
# 15    2013          Belgium                           Bi-fuel   NaN
# 18    2013          Denmark   Liquefied petroleum gases (LPG)   NaN
# 20    2013          Denmark                       Natural Gas   NaN
# 21    2013          Denmark                       Electricity   NaN
# 22    2013          Denmark                Alternative Energy   NaN
# 23    2013          Denmark      Petrol (excluding hybrids)     NaN
# 24    2013          Denmark            Hybrid electric-petrol   NaN
# 25    2013          Denmark  Plug-in hybrid petrol-electric     NaN
# 26    2013          Denmark      Diesel (excluding hybrids)     NaN
# 27    2013          Denmark            Hybrid diesel-electric   NaN
# 28    2013          Denmark  Plug-in hybrid diesel-electric     NaN
# 29    2013          Denmark          Hydrogen and fuel cells    NaN
# 30    2013          Denmark                        Bioethanol   NaN
# 31    2013          Denmark                         Biodiesel   NaN
# 32    2013          Denmark                           Bi-fuel   NaN
# 33    2013          Denmark                             Other   NaN
# 40    2013          Germany      Petrol (excluding hybrids)     NaN
# 41    2013          Germany            Hybrid electric-petrol   NaN
# 42    2013          Germany  Plug-in hybrid petrol-electric     NaN
# 43    2013          Germany      Diesel (excluding hybrids)     NaN
# 44    2013          Germany            Hybrid diesel-electric   NaN
# 45    2013          Germany  Plug-in hybrid diesel-electric     NaN
# 46    2013          Germany          Hydrogen and fuel cells    NaN
# 47    2013          Germany                        Bioethanol   NaN
# ...    ...              ...                               ...   ...
# 2305  2017    Liechtenstein            Hybrid diesel-electric   NaN
# 2306  2017    Liechtenstein  Plug-in hybrid diesel-electric     NaN
# 2307  2017    Liechtenstein          Hydrogen and fuel cells    NaN
# 2308  2017    Liechtenstein                        Bioethanol   NaN
# 2309  2017    Liechtenstein                         Biodiesel   NaN
# 2310  2017    Liechtenstein                           Bi-fuel   NaN
# 2311  2017    Liechtenstein                             Other   NaN
# 2313  2017           Norway   Liquefied petroleum gases (LPG)   NaN
# 2325  2017           Norway                        Bioethanol   NaN
# 2326  2017           Norway                         Biodiesel   NaN
# 2327  2017           Norway                           Bi-fuel   NaN
# 2337  2017      Switzerland  Plug-in hybrid petrol-electric     NaN
# 2340  2017      Switzerland  Plug-in hybrid diesel-electric     NaN
# 2346  2017  North Macedonia                Petroleum products   NaN
# 2347  2017  North Macedonia   Liquefied petroleum gases (LPG)   NaN
# 2348  2017  North Macedonia                            Diesel   NaN
# 2349  2017  North Macedonia                       Natural Gas   NaN
# 2350  2017  North Macedonia                       Electricity   NaN
# 2351  2017  North Macedonia                Alternative Energy   NaN
# 2352  2017  North Macedonia      Petrol (excluding hybrids)     NaN
# 2353  2017  North Macedonia            Hybrid electric-petrol   NaN
# 2354  2017  North Macedonia  Plug-in hybrid petrol-electric     NaN
# 2355  2017  North Macedonia      Diesel (excluding hybrids)     NaN
# 2356  2017  North Macedonia            Hybrid diesel-electric   NaN
# 2357  2017  North Macedonia  Plug-in hybrid diesel-electric     NaN
# 2358  2017  North Macedonia          Hydrogen and fuel cells    NaN
# 2359  2017  North Macedonia                        Bioethanol   NaN
# 2360  2017  North Macedonia                         Biodiesel   NaN
# 2361  2017  North Macedonia                           Bi-fuel   NaN
# 2362  2017  North Macedonia                             Other   NaN
#
# [939 rows x 4 columns]

# %%
df.fillna(0,inplace=True)

# %%
df.dtypes
# Out:
# time        int64
# country    object
# motor      object
# value      object
# dtype: object

# %%
def remove_comma(x):
    return str(x).replace(',','')
df.value = df.value.apply(remove_comma).astype(int)

# %%
df.dtypes
# Out:
# time        int64
# country    object
# motor      object
# value       int64
# dtype: object

# %% [markdown]
# ## Column: motor type

# %%
df['motor'].unique()
# Out:
# array(['Petroleum products', 'Liquefied petroleum gases (LPG)', 'Diesel',
#        'Natural Gas', 'Electricity', 'Alternative Energy',
#        'Petrol (excluding hybrids) \xa0', 'Hybrid electric-petrol',
#        'Plug-in hybrid petrol-electric \xa0',
#        'Diesel (excluding hybrids) \xa0', 'Hybrid diesel-electric',
#        'Plug-in hybrid diesel-electric \xa0',
#        'Hydrogen and fuel cells\xa0', 'Bioethanol', 'Biodiesel',
#        'Bi-fuel', 'Other'], dtype=object)

# %%
# Will also remove \xa0 etc.
df.motor = df.motor.str.strip()

df.motor.unique()
# Out:
# array(['Petroleum products', 'Liquefied petroleum gases (LPG)', 'Diesel',
#        'Natural Gas', 'Electricity', 'Alternative Energy',
#        'Petrol (excluding hybrids)', 'Hybrid electric-petrol',
#        'Plug-in hybrid petrol-electric', 'Diesel (excluding hybrids)',
#        'Hybrid diesel-electric', 'Plug-in hybrid diesel-electric',
#        'Hydrogen and fuel cells', 'Bioethanol', 'Biodiesel', 'Bi-fuel',
#        'Other'], dtype=object)

# %%
mot_num = df[['motor','value']].groupby('motor').sum().loc[:,'value'].squeeze()
mot_num.plot.bar()

# %% [markdown]
# ### Sanity test

# %%
print(mot_num['Diesel'])
print(mot_num['Diesel (excluding hybrids)'] + mot_num['Hybrid diesel-electric'] + mot_num['Plug-in hybrid diesel-electric'])
# Out:
# 32433533
# 25249092

# %% [markdown]
# The data is inconsistent.

# %%
print(df[df.motor == 'Diesel (excluding hybrids)'])
# Out:
#       time          country                       motor    value
# 9     2013          Belgium  Diesel (excluding hybrids)   318951
# 26    2013          Denmark  Diesel (excluding hybrids)        0
# 43    2013          Germany  Diesel (excluding hybrids)        0
# 60    2013          Estonia  Diesel (excluding hybrids)     7341
# 77    2013          Ireland  Diesel (excluding hybrids)        0
# 94    2013            Spain  Diesel (excluding hybrids)        0
# 111   2013           France  Diesel (excluding hybrids)  1168194
# 128   2013          Croatia  Diesel (excluding hybrids)        0
# 145   2013            Italy  Diesel (excluding hybrids)   707641
# 162   2013           Cyprus  Diesel (excluding hybrids)     2998
# 179   2013           Latvia  Diesel (excluding hybrids)        0
# 196   2013        Lithuania  Diesel (excluding hybrids)        0
# 213   2013          Hungary  Diesel (excluding hybrids)    72343
# 230   2013            Malta  Diesel (excluding hybrids)     5266
# 247   2013      Netherlands  Diesel (excluding hybrids)   103557
# 264   2013          Austria  Diesel (excluding hybrids)   180901
# 281   2013           Poland  Diesel (excluding hybrids)        0
# 298   2013         Portugal  Diesel (excluding hybrids)        0
# 315   2013          Romania  Diesel (excluding hybrids)        0
# 332   2013         Slovenia  Diesel (excluding hybrids)        0
# 349   2013          Finland  Diesel (excluding hybrids)        0
# 366   2013           Sweden  Diesel (excluding hybrids)   175422
# 383   2013   United Kingdom  Diesel (excluding hybrids)        0
# 400   2013    Liechtenstein  Diesel (excluding hybrids)      857
# 417   2013           Norway  Diesel (excluding hybrids)        0
# 434   2013      Switzerland  Diesel (excluding hybrids)   115600
# 451   2013  North Macedonia  Diesel (excluding hybrids)    22778
# 468   2013           Turkey  Diesel (excluding hybrids)   383904
# 485   2014          Belgium  Diesel (excluding hybrids)   303212
# 502   2014          Denmark  Diesel (excluding hybrids)        0
# ...    ...              ...                         ...      ...
# 1879  2016  North Macedonia  Diesel (excluding hybrids)        0
# 1896  2016           Turkey  Diesel (excluding hybrids)   460781
# 1913  2017          Belgium  Diesel (excluding hybrids)   258956
# 1930  2017          Denmark  Diesel (excluding hybrids)        0
# 1947  2017          Germany  Diesel (excluding hybrids)        0
# 1964  2017          Estonia  Diesel (excluding hybrids)     6408
# 1981  2017          Ireland  Diesel (excluding hybrids)    87640
# 1998  2017            Spain  Diesel (excluding hybrids)   680355
# 2015  2017           France  Diesel (excluding hybrids)   978185
# 2032  2017          Croatia  Diesel (excluding hybrids)    71385
# 2049  2017            Italy  Diesel (excluding hybrids)  1130434
# 2066  2017           Cyprus  Diesel (excluding hybrids)    15478
# 2083  2017           Latvia  Diesel (excluding hybrids)     7445
# 2100  2017        Lithuania  Diesel (excluding hybrids)   110312
# 2117  2017          Hungary  Diesel (excluding hybrids)   113161
# 2134  2017            Malta  Diesel (excluding hybrids)     6858
# 2151  2017      Netherlands  Diesel (excluding hybrids)        0
# 2168  2017          Austria  Diesel (excluding hybrids)   175458
# 2185  2017           Poland  Diesel (excluding hybrids)   500112
# 2202  2017         Portugal  Diesel (excluding hybrids)   138712
# 2219  2017          Romania  Diesel (excluding hybrids)        0
# 2236  2017         Slovenia  Diesel (excluding hybrids)    32410
# 2253  2017          Finland  Diesel (excluding hybrids)    36062
# 2270  2017           Sweden  Diesel (excluding hybrids)   191059
# 2287  2017   United Kingdom  Diesel (excluding hybrids)  1047685
# 2304  2017    Liechtenstein  Diesel (excluding hybrids)        0
# 2321  2017           Norway  Diesel (excluding hybrids)    44349
# 2338  2017      Switzerland  Diesel (excluding hybrids)   113800
# 2355  2017  North Macedonia  Diesel (excluding hybrids)        0
# 2372  2017           Turkey  Diesel (excluding hybrids)   457060
#
# [140 rows x 4 columns]

# %%
df[(df.time==2017) & (df.country=='Germany')]
# Out:
#       time  country                            motor    value
# 1938  2017  Germany               Petroleum products  1986488
# 1939  2017  Germany  Liquefied petroleum gases (LPG)     4400
# 1940  2017  Germany                           Diesel  1336776
# 1941  2017  Germany                      Natural Gas     3723
# 1942  2017  Germany                      Electricity    25056
# 1943  2017  Germany               Alternative Energy   143474
# 1944  2017  Germany       Petrol (excluding hybrids)        0
# 1945  2017  Germany           Hybrid electric-petrol        0
# 1946  2017  Germany   Plug-in hybrid petrol-electric        0
# 1947  2017  Germany       Diesel (excluding hybrids)        0
# 1948  2017  Germany           Hybrid diesel-electric        0
# 1949  2017  Germany   Plug-in hybrid diesel-electric        0
# 1950  2017  Germany          Hydrogen and fuel cells        0
# 1951  2017  Germany                       Bioethanol        0
# 1952  2017  Germany                        Biodiesel        0
# 1953  2017  Germany                          Bi-fuel        0
# 1954  2017  Germany                            Other   114255

# %%
df.to_csv('../data/road_eqr_carpda_pre.csv',header=True,index=False)

# %% [markdown]
# ## Combine sparse classes in motor column

# %%
print(len(df.query('motor == "Diesel (excluding hybrids)" and value == 0')))
len(df.query('motor == "Diesel" and value==0'))
# Out:
# 49
# 19

# %%
df2 = df.copy()

# %% [markdown]
# ## Step 1
#
# * Drop 'X (excluding hybrids)' (due to lack of data)
# * Drop 'Alternative energy' (since it is merely the sum of 'electric' and 'other')

# %%
df2=df2[~df.motor.isin(['Diesel (excluding hybrids)','Petrol (excluding hybrids)','Alternative Energy'])]
df2.motor.unique()
# Out:
# array(['Petroleum products', 'Liquefied petroleum gases (LPG)', 'Diesel',
#        'Natural Gas', 'Electricity', 'Hybrid electric-petrol',
#        'Plug-in hybrid petrol-electric', 'Hybrid diesel-electric',
#        'Plug-in hybrid diesel-electric', 'Hydrogen and fuel cells',
#        'Bioethanol', 'Biodiesel', 'Bi-fuel', 'Other'], dtype=object)

# %% [markdown]
# ## Step 2
#
# * Keep 'Diesel', 'Petroleum products' and 'Electric'
# * Combine all hybrids into one
# * Combine all alternative energies into 'other'

# %%
df2.motor.replace('Petroleum products', 'petroleum', inplace=True)
df2.motor.replace('Diesel', 'diesel', inplace=True)
df2.motor.replace('Electricity', 'electricity', inplace=True)

df2.motor.replace(['Hybrid electric-petrol', 'Plug-in hybrid petrol-electric', 'Hybrid diesel-electric', 'Plug-in hybrid diesel-electric'], 'hybrid', inplace=True)
df2.motor.replace(['Liquefied petroleum gases (LPG)', 'Natural Gas', 'Hydrogen and fuel cells', 'Bioethanol', 'Biodiesel', 'Bi-fuel', 'Other'], 'other', inplace=True)

df2.motor.unique()
# Out:
# array(['petroleum', 'other', 'diesel', 'electricity', 'hybrid'],
#       dtype=object)

# %%
df2.describe()
# Out:
#               time         value
# count  1960.000000  1.960000e+03
# mean   2015.000000  3.402595e+04
# std       1.414574  1.636310e+05
# min    2013.000000  0.000000e+00
# 25%    2014.000000  0.000000e+00
# 50%    2015.000000  0.000000e+00
# 75%    2016.000000  5.790000e+02
# max    2017.000000  1.986488e+06

# %%
df2.head()
# Out:
#    time  country        motor   value
# 0  2013  Belgium    petroleum  169665
# 1  2013  Belgium        other       0
# 2  2013  Belgium       diesel  319863
# 3  2013  Belgium        other     109
# 4  2013  Belgium  electricity     501

# %%
df3 = pd.DataFrame(columns=df2.columns)
for (i,row) in df2.drop('value',axis=1).drop_duplicates().iterrows():
    partial = df2[(df2.time==row.time) & (df2.country==row.country) & (df2.motor==row.motor)]
    row['value'] = partial.value.sum()
    #print(row.motor, len(partial))
    df3 = df3.append(row)
df3.head()
# Out:
#    time  country        motor   value
# 0  2013  Belgium    petroleum  169665
# 1  2013  Belgium        other     340
# 2  2013  Belgium       diesel  319863
# 4  2013  Belgium  electricity     501
# 7  2013  Belgium       hybrid    5832

# %%
df3[df3.country.isin(['Netherlands','Belgium','Norway'])].head()
# Out:
#    time  country        motor   value
# 0  2013  Belgium    petroleum  169665
# 1  2013  Belgium        other     340
# 2  2013  Belgium       diesel  319863
# 4  2013  Belgium  electricity     501
# 7  2013  Belgium       hybrid    5832

# %% [markdown]
# ## Find countries without data on electric cars

# %%
elec_by_country = df3[df3.motor=='electricity'].groupby('country').value.max()
elec_by_country[elec_by_country == 0]
# Out:
# country
# Denmark            0
# Italy              0
# North Macedonia    0
# Name: value, dtype: int64

# %% [markdown]
# **This dataset does not contain data on electric cars in Denmark and Italy!**

# %% [markdown]
# ## Write end result

# %%
df3.to_csv('../data/road_eqr_carpda_cleaned.csv',index=False,header=True)
